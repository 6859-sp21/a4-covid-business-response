# %%
import pandas as pd
import json
import numpy as np

# %%
df_covid = pd.read_json('yelp_academic_dataset_covid_features.json', lines=True)
# https://medium.com/13-fund/analyzing-covid-19-restaurant-closures-with-yelp-data-f9116c7d563a
# November 2020

# %%
df_businesses = pd.read_json('yelp_academic_dataset_business.json', lines=True)

# %%
df_all = pd.merge(df_businesses, df_covid, on='business_id', how='inner')

# %%
states_to_keep = ['AZ', 'NC', 'NV', 'OH', 'ON', 'PA', 'QC']
columns_to_group = ['state','delivery or takeout']

# %%
df_all = df_all.loc[lambda f: f['is_open'] == 1]
df_all = df_all.loc[lambda f: f['state'].isin(states_to_keep)]

# %%
df_all['category'] = df_all['categories'].apply(lambda x: 'Other' if x is None
                                 else'Restaurant' if 'restaurant' in str.lower(x)
                                 #else 'Health' if 'health' in str.lower(x)
                                 else 'Services' if 'services' in str.lower(x)
                                 else 'Services' if 'auto' in str.lower(x)
                                 else 'Shopping' if 'shopping' in str.lower(x)
                                # else 'Entertainment' if 'art' in str.lower(x)       
                                 #else 'Entertainment' if 'entertainment' in str.lower(x)
                                 else 'Shopping' if 'food' in str.lower(x)
                                 else 'Other')
df_all['Delivery or virtual'] = (df_all['delivery or takeout'] == 'TRUE') | (df_all['Grubhub enabled'] == 'TRUE')  | (df_all['Virtual Services Offered'] == 'TRUE')
df_all['Delivery or virtual'] = np.where(df_all['Delivery or virtual']==True, 'Delivery or virtual', 'No delivery or virtual')
df_all['Call To Action enabled'] = np.where(df_all['Call To Action enabled']=='TRUE', 'Call to Action Enabled', 'No Call to Action')

# %%
# Level 1: State
# Level 2: Category
# Level 3: Call To Action enabled 
# Level 4: Delivery or virtual

# %%
df_gp = df_all.groupby(['state', 'category', #'Call To Action enabled', 
                        'Delivery or virtual'])['business_id'].count().reset_index()

df_gp_2 = df_gp.groupby(['state', 'category'])['business_id'].sum().reset_index()
df_gp = pd.merge(df_gp, df_gp_2, on=['state', 'category'])
df_gp['rate'] = round((df_gp['business_id_x'] / df_gp['business_id_y'])*100,0)
#df_gp['Delivery or virtual'] = df_gp['Delivery or virtual'] + '/n' + df_gp['rate'].astype(str) + '%'
df_gp.rename(columns = {'business_id_x':'business_id'}, inplace = True)
df_gp = df_gp[['state', 'category', 'Delivery or virtual', 'business_id']]

# %%
state_map = {'AZ':'Arizona', 'QC': 'Quebec', 'ON':'Ontario', 'OH': 'Ohio', 'PA':'Pennsylvania', 'NV':'Nevada', 'NC':'North Carolina'}

# %%
df_gp['state'] = df_gp['state'].map(state_map)

# %%
class Node(object):
    def __init__(self, name, children = None, value = None):
        self.name = name
        self.children = children
        self.value = value

# %%
def create_node(field, name, df):
    order = ['Overall', 'state', 'category',# 'Call To Action enabled',
             'Delivery or virtual']
    ix_field = order.index(field)
    if (ix_field == (len(order) - 1)): # If last level
        cur_df = df[df[field] == name]
        return Node(name, value=str(cur_df['business_id'].values[0]))
    else:
        next_field = order[ix_field+1]
        children = [create_node(next_field,name_val, df[df[next_field] == name_val]) for name_val in df[next_field].drop_duplicates().values]
        return Node(name, children=children, value='')

# %%
new_node = create_node('Overall', 'State / Province', df_gp)

# %%
def print_node(node):
    if node.children is not None:
        print('{')
        print('"name": "{}",'.format(node.name))
        print('"children": [')
        for child in node.children:
            print_node(child)
        print("]")
        print("},")
    else:
        print("{" + '"name": "{}", "value": {}'.format(node.name, node.value) + "},")

# %%
print_node(new_node)
# Out:
# {
# "name": "State / Province",
# "children": [
# {
# "name": "Arizona",
# "children": [
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual/n0.0%", "value": 38},
# {"name": "No delivery or virtual/n100.0%", "value": 12442},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual/n93.0%", "value": 7365},
# {"name": "No delivery or virtual/n7.0%", "value": 514},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual/n4.0%", "value": 822},
# {"name": "No delivery or virtual/n96.0%", "value": 22023},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual/n26.0%", "value": 1679},
# {"name": "No delivery or virtual/n74.0%", "value": 4716},
# ]
# },
# ]
# },
# {
# "name": "North Carolina",
# "children": [
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual/n0.0%", "value": 7},
# {"name": "No delivery or virtual/n100.0%", "value": 2970},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual/n94.0%", "value": 3124},
# {"name": "No delivery or virtual/n6.0%", "value": 193},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual/n5.0%", "value": 241},
# {"name": "No delivery or virtual/n95.0%", "value": 4693},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual/n31.0%", "value": 707},
# {"name": "No delivery or virtual/n69.0%", "value": 1553},
# ]
# },
# ]
# },
# {
# "name": "Nevada",
# "children": [
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual/n0.0%", "value": 19},
# {"name": "No delivery or virtual/n100.0%", "value": 7848},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual/n91.0%", "value": 4839},
# {"name": "No delivery or virtual/n9.0%", "value": 485},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual/n4.0%", "value": 488},
# {"name": "No delivery or virtual/n96.0%", "value": 13128},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual/n25.0%", "value": 1104},
# {"name": "No delivery or virtual/n75.0%", "value": 3381},
# ]
# },
# ]
# },
# {
# "name": "Ohio",
# "children": [
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual/n1.0%", "value": 28},
# {"name": "No delivery or virtual/n99.0%", "value": 2704},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual/n93.0%", "value": 4045},
# {"name": "No delivery or virtual/n7.0%", "value": 304},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual/n5.0%", "value": 216},
# {"name": "No delivery or virtual/n95.0%", "value": 4120},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual/n32.0%", "value": 747},
# {"name": "No delivery or virtual/n68.0%", "value": 1608},
# ]
# },
# ]
# },
# {
# "name": "Ontario",
# "children": [
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual/n1.0%", "value": 39},
# {"name": "No delivery or virtual/n99.0%", "value": 5454},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual/n87.0%", "value": 9624},
# {"name": "No delivery or virtual/n13.0%", "value": 1463},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual/n3.0%", "value": 169},
# {"name": "No delivery or virtual/n97.0%", "value": 5736},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual/n33.0%", "value": 1986},
# {"name": "No delivery or virtual/n67.0%", "value": 3974},
# ]
# },
# ]
# },
# {
# "name": "Pennsylvania",
# "children": [
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual/n1.0%", "value": 19},
# {"name": "No delivery or virtual/n99.0%", "value": 2078},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual/n92.0%", "value": 2780},
# {"name": "No delivery or virtual/n8.0%", "value": 232},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual/n5.0%", "value": 152},
# {"name": "No delivery or virtual/n95.0%", "value": 3108},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual/n32.0%", "value": 591},
# {"name": "No delivery or virtual/n68.0%", "value": 1260},
# ]
# },
# ]
# },
# {
# "name": "Quebec",
# "children": [
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual/n0.0%", "value": 3},
# {"name": "No delivery or virtual/n100.0%", "value": 1099},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual/n72.0%", "value": 3374},
# {"name": "No delivery or virtual/n28.0%", "value": 1304},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual/n5.0%", "value": 47},
# {"name": "No delivery or virtual/n95.0%", "value": 859},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual/n37.0%", "value": 562},
# {"name": "No delivery or virtual/n63.0%", "value": 967},
# ]
# },
# ]
# },
# ]
# },
