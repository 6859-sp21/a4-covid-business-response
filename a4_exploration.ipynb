# %%
import pandas as pd
import json
import numpy as np

# %%
df_covid = pd.read_json('yelp_academic_dataset_covid_features.json', lines=True)
# https://medium.com/13-fund/analyzing-covid-19-restaurant-closures-with-yelp-data-f9116c7d563a
# November 2020

# %%
df_businesses = pd.read_json('yelp_academic_dataset_business.json', lines=True)

# %%
df_all = pd.merge(df_businesses, df_covid, on='business_id', how='inner')

# %%
states_to_keep = ['AZ', 'NC', 'NV', 'OH', 'ON', 'PA', 'QC']
columns_to_group = ['state','delivery or takeout']

# %%
df_all = df_all.loc[lambda f: f['is_open'] == 1]
df_all = df_all.loc[lambda f: f['state'].isin(states_to_keep)]

# %%
df_all['category'] = df_all['categories'].apply(lambda x: 'Other' if x is None
                                 else'Restaurant' if 'restaurant' in str.lower(x)
                                 else 'Health' if 'health' in str.lower(x)
                                 else 'Services' if 'services' in str.lower(x)
                                 else 'Services' if 'auto' in str.lower(x)
                                 else 'Shopping' if 'shopping' in str.lower(x)
                                # else 'Entertainment' if 'art' in str.lower(x)       
                                 #else 'Entertainment' if 'entertainment' in str.lower(x)
                                 else 'Shopping' if 'food' in str.lower(x)
                                 else 'Other')
df_all['Delivery or virtual'] = (df_all['delivery or takeout'] == 'TRUE') | (df_all['Grubhub enabled'] == 'TRUE')  | (df_all['Virtual Services Offered'] == 'TRUE')
df_all['Delivery or virtual'] = np.where(df_all['Delivery or virtual']==True, 'Delivery or virtual', 'No delivery or virtual')
df_all['Call To Action enabled'] = np.where(df_all['Call To Action enabled']=='TRUE', 'Call to Action Enabled', 'No Call to Action')

# %%
# Level 1: State
# Level 2: Category
# Level 3: Call To Action enabled 
# Level 4: Delivery or virtual

# %%
df_gp = df_all.groupby(['state', 'category', #'Call To Action enabled', 
                        'Delivery or virtual'])['business_id'].count().reset_index()

# %%
class Node(object):
    def __init__(self, name, children = None, value = None):
        self.name = name
        self.children = children
        self.value = value

# %%
def create_node(field, name, df):
    order = ['Overall', 'state', 'category',# 'Call To Action enabled',
             'Delivery or virtual']
    ix_field = order.index(field)
    if (ix_field == (len(order) - 1)): # If last level
        cur_df = df[df[field] == name]
        return Node(name, value=str(cur_df['business_id'].values[0]))
    else:
        next_field = order[ix_field+1]
        children = [create_node(next_field,name_val, df[df[next_field] == name_val]) for name_val in df[next_field].drop_duplicates().values]
        return Node(name, children=children, value='')

# %%
df_on = df_gp[df_gp['state'] == 'ON']
#new_node = create_node('state', 'ON', df_on)
new_node = create_node('Overall', 'State / Province', df_gp)

# %%
def print_node(node):
    if node.children is not None:
        print('{')
        print('"name": "{}",'.format(node.name))
        print('"children": [')
        for child in node.children:
            print_node(child)
        print("]")
        print("},")
    else:
        print("{" + '"name": "{}", "value": {}'.format(node.name, node.value) + "},")

# %%
print_node(new_node)
# Out:
# {
# "name": "All",
# "children": [
# {
# "name": "AZ",
# "children": [
# {
# "name": "Health",
# "children": [
# {"name": "Delivery or virtual", "value": 187},
# {"name": "No delivery or virtual", "value": 7421},
# ]
# },
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual", "value": 38},
# {"name": "No delivery or virtual", "value": 6328},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual", "value": 7365},
# {"name": "No delivery or virtual", "value": 514},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual", "value": 810},
# {"name": "No delivery or virtual", "value": 21284},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual", "value": 1504},
# {"name": "No delivery or virtual", "value": 4148},
# ]
# },
# ]
# },
# {
# "name": "NC",
# "children": [
# {
# "name": "Health",
# "children": [
# {"name": "Delivery or virtual", "value": 77},
# {"name": "No delivery or virtual", "value": 1268},
# ]
# },
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual", "value": 7},
# {"name": "No delivery or virtual", "value": 1932},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual", "value": 3124},
# {"name": "No delivery or virtual", "value": 193},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual", "value": 239},
# {"name": "No delivery or virtual", "value": 4607},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual", "value": 632},
# {"name": "No delivery or virtual", "value": 1409},
# ]
# },
# ]
# },
# {
# "name": "NV",
# "children": [
# {
# "name": "Health",
# "children": [
# {"name": "Delivery or virtual", "value": 114},
# {"name": "No delivery or virtual", "value": 4046},
# ]
# },
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual", "value": 16},
# {"name": "No delivery or virtual", "value": 4550},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual", "value": 4839},
# {"name": "No delivery or virtual", "value": 485},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual", "value": 472},
# {"name": "No delivery or virtual", "value": 12728},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual", "value": 1009},
# {"name": "No delivery or virtual", "value": 3033},
# ]
# },
# ]
# },
# {
# "name": "OH",
# "children": [
# {
# "name": "Health",
# "children": [
# {"name": "Delivery or virtual", "value": 102},
# {"name": "No delivery or virtual", "value": 900},
# ]
# },
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual", "value": 28},
# {"name": "No delivery or virtual", "value": 2004},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual", "value": 4045},
# {"name": "No delivery or virtual", "value": 304},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual", "value": 211},
# {"name": "No delivery or virtual", "value": 4050},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual", "value": 650},
# {"name": "No delivery or virtual", "value": 1478},
# ]
# },
# ]
# },
# {
# "name": "ON",
# "children": [
# {
# "name": "Health",
# "children": [
# {"name": "Delivery or virtual", "value": 74},
# {"name": "No delivery or virtual", "value": 1783},
# ]
# },
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual", "value": 38},
# {"name": "No delivery or virtual", "value": 4064},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual", "value": 9624},
# {"name": "No delivery or virtual", "value": 1463},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual", "value": 163},
# {"name": "No delivery or virtual", "value": 5644},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual", "value": 1919},
# {"name": "No delivery or virtual", "value": 3673},
# ]
# },
# ]
# },
# {
# "name": "PA",
# "children": [
# {
# "name": "Health",
# "children": [
# {"name": "Delivery or virtual", "value": 25},
# {"name": "No delivery or virtual", "value": 776},
# ]
# },
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual", "value": 18},
# {"name": "No delivery or virtual", "value": 1476},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual", "value": 2780},
# {"name": "No delivery or virtual", "value": 232},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual", "value": 147},
# {"name": "No delivery or virtual", "value": 3046},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual", "value": 572},
# {"name": "No delivery or virtual", "value": 1148},
# ]
# },
# ]
# },
# {
# "name": "QC",
# "children": [
# {
# "name": "Health",
# "children": [
# {"name": "Delivery or virtual", "value": 14},
# {"name": "No delivery or virtual", "value": 217},
# ]
# },
# {
# "name": "Other",
# "children": [
# {"name": "Delivery or virtual", "value": 3},
# {"name": "No delivery or virtual", "value": 957},
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {"name": "Delivery or virtual", "value": 3374},
# {"name": "No delivery or virtual", "value": 1304},
# ]
# },
# {
# "name": "Services",
# "children": [
# {"name": "Delivery or virtual", "value": 47},
# {"name": "No delivery or virtual", "value": 853},
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {"name": "Delivery or virtual", "value": 548},
# {"name": "No delivery or virtual", "value": 898},
# ]
# },
# ]
# },
# ]
# },
