# %%
import pandas as pd
import json
import numpy as np

# %%
df_covid = pd.read_json('yelp_academic_dataset_covid_features.json', lines=True)
# https://medium.com/13-fund/analyzing-covid-19-restaurant-closures-with-yelp-data-f9116c7d563a
# November 2020

# %%
df_businesses = pd.read_json('yelp_academic_dataset_business.json', lines=True)

# %%
df_all = pd.merge(df_businesses, df_covid, on='business_id', how='inner')

# %%
states_to_keep = ['AB', 'AZ', 'IL', 'NC', 'NV', 'OH', 'ON', 'PA', 'QC', 'SC', 'WI']
columns_to_group = ['state','delivery or takeout']

# %%
df_all = df_all.loc[lambda f: f['is_open'] == 1]
df_all = df_all.loc[lambda f: f['state'].isin(states_to_keep)]

# %%
df_all['category'] = df_all['categories'].apply(lambda x: 'Other' if x is None
                                 else'Restaurant' if 'restaurant' in str.lower(x)
                                 else 'Health' if 'health' in str.lower(x)
                                 else 'Services' if 'services' in str.lower(x)
                                 else 'Services' if 'auto' in str.lower(x)
                                 else 'Shopping' if 'shopping' in str.lower(x)
                                 else 'Entertainment' if 'art' in str.lower(x)       
                                 else 'Entertainment' if 'entertainment' in str.lower(x)
                                 else 'Shopping' if 'food' in str.lower(x)
                                 else 'Other')
df_all['Delivery or virtual'] = (df_all['delivery or takeout'] == 'TRUE') | (df_all['Grubhub enabled'] == 'TRUE')  | (df_all['Virtual Services Offered'] == 'TRUE')
df_all['Delivery or virtual'] = np.where(df_all['Delivery or virtual']==True, 'Delivery or virtual', 'No delivery or virtual')
df_all['Call To Action enabled'] = np.where(df_all['Call To Action enabled']=='TRUE', 'Call to Action Enabled', 'No Call to Action')

# %%
# Level 1: State
# Level 2: Category
# Level 3: Call To Action enabled 
# Level 4: Delivery or virtual
# Out:
# 'Festivals, Arts & Entertainment'

# %%
df_gp = df_all.groupby(['state', 'category', 'Call To Action enabled', 'Delivery or virtual'])['business_id'].count().reset_index()

# %%
class Node(object):
    def __init__(self, name, children = None, value = None):
        self.name = name
        self.children = children
        self.value = value

# %%
def create_node(field, name, df):
    order = ['Overall', 'state', 'category', 'Call To Action enabled', 'Delivery or virtual']
    ix_field = order.index(field)
    if (ix_field == (len(order) - 1)): # If last level
        cur_df = df[df[field] == name]
        return Node(name, value=str(cur_df['business_id'].values[0]))
    else:
        next_field = order[ix_field+1]
        children = [create_node(next_field,name_val, df[df[next_field] == name_val]) for name_val in df[next_field].drop_duplicates().values]
        return Node(name, children=children, value='')

# %%
df_on = df_gp[df_gp['state'] == 'ON']
#new_node = create_node('state', 'ON', df_on)
new_node = create_node('Overall', 'All', df_gp)

# %%
def print_node(node):
    if node.children is not None:
        print('{')
        print('"name": "{}",'.format(node.name))
        print('"children": [')
        for child in node.children:
            print_node(child)
        print("]")
        print("},")
    else:
        print("{" + '"name": "{}", "value": {}'.format(node.name, node.value) + "},")

# %%
print_node(new_node)
# Out:
# {
# "name": "All",
# "children": [
# {
# "name": "AB",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 14},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 2},
# {"name": "No delivery or virtual", "value": 98},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 85},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 17},
# {"name": "No delivery or virtual", "value": 393},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 1},
# {"name": "No delivery or virtual", "value": 119},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 13},
# {"name": "No delivery or virtual", "value": 741},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 352},
# {"name": "No delivery or virtual", "value": 21},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 1709},
# {"name": "No delivery or virtual", "value": 289},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 2},
# {"name": "No delivery or virtual", "value": 340},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 31},
# {"name": "No delivery or virtual", "value": 1419},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 22},
# {"name": "No delivery or virtual", "value": 105},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 346},
# {"name": "No delivery or virtual", "value": 922},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "AZ",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 5},
# {"name": "No delivery or virtual", "value": 203},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 28},
# {"name": "No delivery or virtual", "value": 633},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 138},
# {"name": "No delivery or virtual", "value": 2381},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 49},
# {"name": "No delivery or virtual", "value": 5040},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 2},
# {"name": "No delivery or virtual", "value": 1347},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 17},
# {"name": "No delivery or virtual", "value": 4170},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 3498},
# {"name": "No delivery or virtual", "value": 138},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 3867},
# {"name": "No delivery or virtual", "value": 376},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 379},
# {"name": "No delivery or virtual", "value": 8542},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 431},
# {"name": "No delivery or virtual", "value": 12742},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 689},
# {"name": "No delivery or virtual", "value": 1117},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 801},
# {"name": "No delivery or virtual", "value": 3006},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "IL",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 4},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 2},
# {"name": "No delivery or virtual", "value": 19},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 3},
# {"name": "No delivery or virtual", "value": 26},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 5},
# {"name": "No delivery or virtual", "value": 71},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 29},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 1},
# {"name": "No delivery or virtual", "value": 164},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 161},
# {"name": "No delivery or virtual", "value": 4},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 266},
# {"name": "No delivery or virtual", "value": 30},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 19},
# {"name": "No delivery or virtual", "value": 192},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 12},
# {"name": "No delivery or virtual", "value": 376},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 21},
# {"name": "No delivery or virtual", "value": 37},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 41},
# {"name": "No delivery or virtual", "value": 115},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "NC",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 52},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 6},
# {"name": "No delivery or virtual", "value": 221},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 43},
# {"name": "No delivery or virtual", "value": 318},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 34},
# {"name": "No delivery or virtual", "value": 950},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 3},
# {"name": "No delivery or virtual", "value": 323},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 4},
# {"name": "No delivery or virtual", "value": 1349},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 1284},
# {"name": "No delivery or virtual", "value": 30},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 1840},
# {"name": "No delivery or virtual", "value": 163},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 143},
# {"name": "No delivery or virtual", "value": 1721},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 96},
# {"name": "No delivery or virtual", "value": 2886},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 227},
# {"name": "No delivery or virtual", "value": 301},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 399},
# {"name": "No delivery or virtual", "value": 1095},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "NV",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 3},
# {"name": "No delivery or virtual", "value": 301},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 8},
# {"name": "No delivery or virtual", "value": 708},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 97},
# {"name": "No delivery or virtual", "value": 1178},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 17},
# {"name": "No delivery or virtual", "value": 2868},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 1},
# {"name": "No delivery or virtual", "value": 869},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 12},
# {"name": "No delivery or virtual", "value": 2703},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 2382},
# {"name": "No delivery or virtual", "value": 189},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 2457},
# {"name": "No delivery or virtual", "value": 296},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 292},
# {"name": "No delivery or virtual", "value": 4969},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 180},
# {"name": "No delivery or virtual", "value": 7759},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 494},
# {"name": "No delivery or virtual", "value": 808},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 507},
# {"name": "No delivery or virtual", "value": 2194},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "OH",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 2},
# {"name": "No delivery or virtual", "value": 46},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 11},
# {"name": "No delivery or virtual", "value": 228},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 44},
# {"name": "No delivery or virtual", "value": 243},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 58},
# {"name": "No delivery or virtual", "value": 657},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 2},
# {"name": "No delivery or virtual", "value": 274},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 24},
# {"name": "No delivery or virtual", "value": 1469},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 1418},
# {"name": "No delivery or virtual", "value": 38},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 2627},
# {"name": "No delivery or virtual", "value": 266},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 115},
# {"name": "No delivery or virtual", "value": 1267},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 96},
# {"name": "No delivery or virtual", "value": 2783},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 184},
# {"name": "No delivery or virtual", "value": 272},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 455},
# {"name": "No delivery or virtual", "value": 1193},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "ON",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 1},
# {"name": "No delivery or virtual", "value": 66},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 8},
# {"name": "No delivery or virtual", "value": 409},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 16},
# {"name": "No delivery or virtual", "value": 323},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 58},
# {"name": "No delivery or virtual", "value": 1460},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 5},
# {"name": "No delivery or virtual", "value": 521},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 31},
# {"name": "No delivery or virtual", "value": 3091},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 1887},
# {"name": "No delivery or virtual", "value": 120},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 7737},
# {"name": "No delivery or virtual", "value": 1343},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 48},
# {"name": "No delivery or virtual", "value": 899},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 115},
# {"name": "No delivery or virtual", "value": 4745},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 308},
# {"name": "No delivery or virtual", "value": 376},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 1604},
# {"name": "No delivery or virtual", "value": 3274},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "PA",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 3},
# {"name": "No delivery or virtual", "value": 25},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 4},
# {"name": "No delivery or virtual", "value": 158},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 19},
# {"name": "No delivery or virtual", "value": 211},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 6},
# {"name": "No delivery or virtual", "value": 565},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 2},
# {"name": "No delivery or virtual", "value": 221},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 16},
# {"name": "No delivery or virtual", "value": 1089},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 856},
# {"name": "No delivery or virtual", "value": 33},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 1924},
# {"name": "No delivery or virtual", "value": 199},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 64},
# {"name": "No delivery or virtual", "value": 916},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 83},
# {"name": "No delivery or virtual", "value": 2130},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 165},
# {"name": "No delivery or virtual", "value": 249},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 400},
# {"name": "No delivery or virtual", "value": 882},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "QC",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 7},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 3},
# {"name": "No delivery or virtual", "value": 192},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 11},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 14},
# {"name": "No delivery or virtual", "value": 206},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 24},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 3},
# {"name": "No delivery or virtual", "value": 745},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 198},
# {"name": "No delivery or virtual", "value": 32},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 3176},
# {"name": "No delivery or virtual", "value": 1272},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 5},
# {"name": "No delivery or virtual", "value": 85},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 42},
# {"name": "No delivery or virtual", "value": 768},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 9},
# {"name": "No delivery or virtual", "value": 33},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 536},
# {"name": "No delivery or virtual", "value": 854},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "SC",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 2},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "No delivery or virtual", "value": 12},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 4},
# {"name": "No delivery or virtual", "value": 30},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 1},
# {"name": "No delivery or virtual", "value": 93},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 23},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "No delivery or virtual", "value": 119},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 109},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 174},
# {"name": "No delivery or virtual", "value": 14},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 10},
# {"name": "No delivery or virtual", "value": 111},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 14},
# {"name": "No delivery or virtual", "value": 246},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 23},
# {"name": "No delivery or virtual", "value": 19},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 45},
# {"name": "No delivery or virtual", "value": 65},
# ]
# },
# ]
# },
# ]
# },
# {
# "name": "WI",
# "children": [
# {
# "name": "Entertainment",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 13},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 1},
# {"name": "No delivery or virtual", "value": 74},
# ]
# },
# ]
# },
# {
# "name": "Health",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 7},
# {"name": "No delivery or virtual", "value": 115},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 5},
# {"name": "No delivery or virtual", "value": 216},
# ]
# },
# ]
# },
# {
# "name": "Other",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "No delivery or virtual", "value": 116},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 4},
# {"name": "No delivery or virtual", "value": 404},
# ]
# },
# ]
# },
# {
# "name": "Restaurant",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 314},
# {"name": "No delivery or virtual", "value": 15},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 781},
# {"name": "No delivery or virtual", "value": 75},
# ]
# },
# ]
# },
# {
# "name": "Services",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 42},
# {"name": "No delivery or virtual", "value": 472},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 35},
# {"name": "No delivery or virtual", "value": 1070},
# ]
# },
# ]
# },
# {
# "name": "Shopping",
# "children": [
# {
# "name": "Call to Action Enabled",
# "children": [
# {"name": "Delivery or virtual", "value": 53},
# {"name": "No delivery or virtual", "value": 93},
# ]
# },
# {
# "name": "No Call to Action",
# "children": [
# {"name": "Delivery or virtual", "value": 130},
# {"name": "No delivery or virtual", "value": 404},
# ]
# },
# ]
# },
# ]
# },
# ]
# },
